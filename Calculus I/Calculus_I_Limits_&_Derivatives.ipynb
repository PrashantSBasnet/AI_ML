# %% [markdown]
# <a href="https://colab.research.google.com/github/PrashantSBasnet/AI_ML/blob/master/Calculus%20I/Calculus_I_Limits_%26_Derivatives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10, 10000) # start, finish, n points

# %%
y = x**2 + 2*x + 2

# %%
fig, ax = plt.subplots()
_ = ax.plot(x,y)

# %%
#zooming in to find m=0

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2, -0])
ax.set_ylim([0, 2])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.5, -0.5])
ax.set_ylim([0.5, 1.5])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.1, -0.9])
ax.set_ylim([0.9, 1.1])
_ = ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-1.01, -0.99])
ax.set_ylim([0.99, 1.01])
_ = ax.plot(x,y)

# %% [markdown]
# Calculus Limits

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-5, 10)
plt.ylim(-10, 80)
plt.axvline(x=5, color='purple', linestyle='--')
plt.axhline(y=37, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
def my_fxn(x):
  my_y=(x**2-1)/(x-1)
  return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
my_fxn(0.9)
# Out:
# 1.9

# %%
my_fxn(1.1)
# Out:
# 2.1

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.001)
# Out:
# 2.0009999999999177

# %%
y=my_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-1, 5)
plt.ylim(-1, 5)
plt.axvline(x=1, color='purple', linestyle='--')
plt.axhline(y=2, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
def sin_fxn(my_x):
    my_y = np.sin(my_x)/my_x
    return my_y

# %%
sin_fxn(0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(0.001)
# Out:
# 0.9999998333333416

# %%
sin_fxn(-0.1)
# Out:
# 0.9983341664682815

# %%
sin_fxn(-0.001)
# Out:
# 0.9999998333333416

# %%
y = sin_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-1, 2)
plt.axvline(x=0, color='purple', linestyle='--')
plt.axhline(y=1, color='purple', linestyle='--')
_ = ax.plot(x,y)

# %%
def inf_fxn(my_x):
    my_y = 25/my_x
    return my_y

# %%
inf_fxn(1e3)
# Out:
# 0.025

# %%
inf_fxn(1e6)
# Out:
# 2.5e-05

# %%
y = inf_fxn(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
_ = ax.plot(x, y)

# %%
left_x = x[x<0]
right_x = x[x>0]

# %%
left_y = inf_fxn(left_x)
right_y = inf_fxn(right_x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.xlim(-10, 10)
plt.ylim(-300, 300)
ax.plot(left_x, left_y, c='C0')
_ = ax.plot(right_x, right_y, c='C0')

# %% [markdown]
# Delta Method

# %%
def f(my_x):
  my_y = my_x*my_x + 2*my_x + 2
  return my_y

# %%
y = f(x)

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
_ = ax.plot(x,y)

# %%
f(2)
# Out:
# 10

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10) # new
_ = ax.plot(x,y)

# %%
f(5)
# Out:
# 37

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c = 'orange', zorder=3) # new
_ = ax.plot(x,y)

# %%
m = (37-10)/(5-2)
m
# Out:
# 9.0

# %%
b = 37-m*5
b
# Out:
# -8.0

# %%
line_y = m*x + b

# %%
fig, ax = plt.subplots()
plt.axvline(x=0, color='lightgray')
plt.axhline(y=0, color='lightgray')
plt.scatter(2, 10)
plt.scatter(5, 37, c='orange', zorder=3)
plt.ylim(-5, 150) # new
plt.plot(x, line_y, c='orange') # new
_ = ax.plot(x,y)

# %% [markdown]
# AutoDiff in Pytorch

# %%
import torch

# %%
x=torch.tensor(5.0) #creating a scalar tensor to store value x

# %%
x.requires_grad_()
# Out:
# tensor(5., requires_grad=True)

# %%
y=x**2

# %%
y.backward() #uses autodiff

# %%
x.grad #slope
# Out:
# tensor(10.)

# %% [markdown]
# AutoDiff in TensorFlow

# %%
import tensorflow as tf
x=tf.Variable(5.0)

# %%
with tf.GradientTape() as t:
  t.watch(x) #track forward pass
  y=x**2

# %%
t.gradient(y,x) #use autodiff
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %% [markdown]
# Regression in PyTorch

# %%
import torch
import matplotlib.pyplot as plt

# %%
x = torch.tensor([0, 1, 2, 3, 4, 5, 6, 7.]) # E.g.: Dosage of drug for treating Alzheimer's disease
x
# Out:
# tensor([0., 1., 2., 3., 4., 5., 6., 7.])

# %%
y = -0.5*x + 2 + torch.normal(mean=torch.zeros(8), std=0.2)
y

# %%
fig, ax = plt.subplots()
plt.title("Clinical Trial")
plt.xlabel("Drug dosage (mL)")
plt.ylabel("Forgetfulness")
_ = ax.scatter(x, y)

# %%
m = torch.tensor([0.9]).requires_grad_()
m
# Out:
# tensor([0.9000], requires_grad=True)

# %%
b = torch.tensor([0.1]).requires_grad_()
b
# Out:
# tensor([0.1000], requires_grad=True)

# %%
def regression(my_x, my_m, my_b):
    return my_m*my_x + my_b

# %%
def regression_plot(my_x, my_y, my_m, my_b):

    fig, ax = plt.subplots()

    ax.scatter(my_x, my_y)

    x_min, x_max = ax.get_xlim()
    y_min = regression(x_min, my_m, my_b).detach().item()
    y_max = regression(x_max, my_m, my_b).detach().item()

    ax.set_xlim([x_min, x_max])
    _ = ax.plot([x_min, x_max], [y_min, y_max])

# %%
regression_plot(x, y, m, b)

# %% [markdown]
# Machine Learning

# %%
yhat = regression(x, m, b)
yhat
# Out:
# tensor([0.1000, 1.0000, 1.9000, 2.8000, 3.7000, 4.6000, 5.5000, 6.4000],
#        grad_fn=<AddBackward0>)

# %%
def mse(my_yhat, my_y):
    sigma = torch.sum((my_yhat - my_y)**2)
    return sigma/len(my_y)

# %%
C = mse(yhat, y)
C
# Out:
# tensor(18.8505, grad_fn=<DivBackward0>)

# %%
C.backward()

# %%
m.grad
# Out:
# tensor([35.2136])

# %%
b.grad
# Out:
# tensor([5.8862])

# %%
optimizer = torch.optim.SGD([m, b], lr=0.01)

# %%
optimizer.step()

# %%
m
# Out:
# tensor([0.5479], requires_grad=True)

# %%
b
# Out:
# tensor([0.0411], requires_grad=True)

# %%
regression_plot(x, y, m, b)

# %%
C = mse(regression(x, m, b), y)
C
# Out:
# tensor(8.4226, grad_fn=<DivBackward0>)

# %%
epochs = 1000
for epoch in range(epochs):

    optimizer.zero_grad() # Reset gradients to zero; else they accumulate

    yhat = regression(x, m, b) # Step 1
    C = mse(yhat, y) # Step 2

    C.backward() # Step 3
    optimizer.step() # Step 4

    print('Epoch {}, cost {}, m grad {}, b grad {}'.format(epoch, '%.3g' % C.item(), '%.3g' % m.grad.item(), '%.3g' % b.grad.item()))
# Out:
# Epoch 0, cost 8.42, m grad 22.5, b grad 3.3
# Epoch 1, cost 4.2, m grad 14.4, b grad 1.66
# Epoch 2, cost 2.48, m grad 9.23, b grad 0.624
# Epoch 3, cost 1.78, m grad 5.96, b grad -0.0343
# Epoch 4, cost 1.49, m grad 3.87, b grad -0.45
# Epoch 5, cost 1.36, m grad 2.55, b grad -0.713
# Epoch 6, cost 1.3, m grad 1.71, b grad -0.877
# Epoch 7, cost 1.27, m grad 1.17, b grad -0.979
# Epoch 8, cost 1.25, m grad 0.83, b grad -1.04
# Epoch 9, cost 1.23, m grad 0.612, b grad -1.08
# Epoch 10, cost 1.21, m grad 0.473, b grad -1.1
# Epoch 11, cost 1.2, m grad 0.385, b grad -1.11
# Epoch 12, cost 1.19, m grad 0.328, b grad -1.12
# Epoch 13, cost 1.17, m grad 0.291, b grad -1.12
# Epoch 14, cost 1.16, m grad 0.267, b grad -1.11
# Epoch 15, cost 1.15, m grad 0.252, b grad -1.11
# Epoch 16, cost 1.13, m grad 0.241, b grad -1.11
# Epoch 17, cost 1.12, m grad 0.234, b grad -1.1
# Epoch 18, cost 1.11, m grad 0.229, b grad -1.1
# Epoch 19, cost 1.1, m grad 0.226, b grad -1.09
# Epoch 20, cost 1.08, m grad 0.223, b grad -1.08
# Epoch 21, cost 1.07, m grad 0.221, b grad -1.08
# Epoch 22, cost 1.06, m grad 0.219, b grad -1.07
# Epoch 23, cost 1.05, m grad 0.217, b grad -1.07
# Epoch 24, cost 1.03, m grad 0.216, b grad -1.06
# Epoch 25, cost 1.02, m grad 0.214, b grad -1.05
# Epoch 26, cost 1.01, m grad 0.213, b grad -1.05
# Epoch 27, cost 1, m grad 0.212, b grad -1.04
# Epoch 28, cost 0.989, m grad 0.211, b grad -1.03
# Epoch 29, cost 0.978, m grad 0.209, b grad -1.03
# Epoch 30, cost 0.967, m grad 0.208, b grad -1.02
# Epoch 31, cost 0.956, m grad 0.207, b grad -1.02
# Epoch 32, cost 0.945, m grad 0.206, b grad -1.01
# Epoch 33, cost 0.935, m grad 0.204, b grad -1.01
# Epoch 34, cost 0.924, m grad 0.203, b grad -1
# Epoch 35, cost 0.914, m grad 0.202, b grad -0.994
# Epoch 36, cost 0.903, m grad 0.201, b grad -0.988
# Epoch 37, cost 0.893, m grad 0.2, b grad -0.982
# Epoch 38, cost 0.883, m grad 0.199, b grad -0.977
# Epoch 39, cost 0.873, m grad 0.197, b grad -0.971
# Epoch 40, cost 0.864, m grad 0.196, b grad -0.966
# Epoch 41, cost 0.854, m grad 0.195, b grad -0.96
# Epoch 42, cost 0.844, m grad 0.194, b grad -0.954
# Epoch 43, cost 0.835, m grad 0.193, b grad -0.949
# Epoch 44, cost 0.826, m grad 0.192, b grad -0.943
# Epoch 45, cost 0.816, m grad 0.191, b grad -0.938
# Epoch 46, cost 0.807, m grad 0.19, b grad -0.933
# Epoch 47, cost 0.798, m grad 0.189, b grad -0.927
# Epoch 48, cost 0.789, m grad 0.187, b grad -0.922
# Epoch 49, cost 0.78, m grad 0.186, b grad -0.917
# Epoch 50, cost 0.772, m grad 0.185, b grad -0.911
# Epoch 51, cost 0.763, m grad 0.184, b grad -0.906
# Epoch 52, cost 0.755, m grad 0.183, b grad -0.901
# Epoch 53, cost 0.746, m grad 0.182, b grad -0.896
# Epoch 54, cost 0.738, m grad 0.181, b grad -0.89
# Epoch 55, cost 0.73, m grad 0.18, b grad -0.885
# Epoch 56, cost 0.721, m grad 0.179, b grad -0.88
# Epoch 57, cost 0.713, m grad 0.178, b grad -0.875
# Epoch 58, cost 0.705, m grad 0.177, b grad -0.87
# Epoch 59, cost 0.698, m grad 0.176, b grad -0.865
# Epoch 60, cost 0.69, m grad 0.175, b grad -0.86
# Epoch 61, cost 0.682, m grad 0.174, b grad -0.855
# Epoch 62, cost 0.674, m grad 0.173, b grad -0.85
# Epoch 63, cost 0.667, m grad 0.172, b grad -0.845
# Epoch 64, cost 0.66, m grad 0.171, b grad -0.84
# Epoch 65, cost 0.652, m grad 0.17, b grad -0.836
# Epoch 66, cost 0.645, m grad 0.169, b grad -0.831
# Epoch 67, cost 0.638, m grad 0.168, b grad -0.826
# Epoch 68, cost 0.631, m grad 0.167, b grad -0.821
# Epoch 69, cost 0.624, m grad 0.166, b grad -0.816
# Epoch 70, cost 0.617, m grad 0.165, b grad -0.812
# Epoch 71, cost 0.61, m grad 0.164, b grad -0.807
# Epoch 72, cost 0.603, m grad 0.163, b grad -0.802
# Epoch 73, cost 0.596, m grad 0.162, b grad -0.798
# Epoch 74, cost 0.59, m grad 0.161, b grad -0.793
# Epoch 75, cost 0.583, m grad 0.16, b grad -0.789
# Epoch 76, cost 0.577, m grad 0.159, b grad -0.784
# Epoch 77, cost 0.571, m grad 0.159, b grad -0.78
# Epoch 78, cost 0.564, m grad 0.158, b grad -0.775
# Epoch 79, cost 0.558, m grad 0.157, b grad -0.771
# Epoch 80, cost 0.552, m grad 0.156, b grad -0.766
# Epoch 81, cost 0.546, m grad 0.155, b grad -0.762
# Epoch 82, cost 0.54, m grad 0.154, b grad -0.757
# Epoch 83, cost 0.534, m grad 0.153, b grad -0.753
# Epoch 84, cost 0.528, m grad 0.152, b grad -0.749
# Epoch 85, cost 0.522, m grad 0.151, b grad -0.744
# Epoch 86, cost 0.516, m grad 0.15, b grad -0.74
# Epoch 87, cost 0.511, m grad 0.15, b grad -0.736
# Epoch 88, cost 0.505, m grad 0.149, b grad -0.732
# Epoch 89, cost 0.499, m grad 0.148, b grad -0.727
# Epoch 90, cost 0.494, m grad 0.147, b grad -0.723
# Epoch 91, cost 0.488, m grad 0.146, b grad -0.719
# Epoch 92, cost 0.483, m grad 0.145, b grad -0.715
# Epoch 93, cost 0.478, m grad 0.145, b grad -0.711
# Epoch 94, cost 0.473, m grad 0.144, b grad -0.707
# Epoch 95, cost 0.467, m grad 0.143, b grad -0.703
# Epoch 96, cost 0.462, m grad 0.142, b grad -0.698
# Epoch 97, cost 0.457, m grad 0.141, b grad -0.694
# Epoch 98, cost 0.452, m grad 0.14, b grad -0.69
# Epoch 99, cost 0.447, m grad 0.14, b grad -0.686
# Epoch 100, cost 0.442, m grad 0.139, b grad -0.683
# Epoch 101, cost 0.437, m grad 0.138, b grad -0.679
# Epoch 102, cost 0.433, m grad 0.137, b grad -0.675
# Epoch 103, cost 0.428, m grad 0.136, b grad -0.671
# Epoch 104, cost 0.423, m grad 0.136, b grad -0.667
# Epoch 105, cost 0.419, m grad 0.135, b grad -0.663
# Epoch 106, cost 0.414, m grad 0.134, b grad -0.659
# Epoch 107, cost 0.41, m grad 0.133, b grad -0.655
# Epoch 108, cost 0.405, m grad 0.133, b grad -0.652
# Epoch 109, cost 0.401, m grad 0.132, b grad -0.648
# Epoch 110, cost 0.396, m grad 0.131, b grad -0.644
# Epoch 111, cost 0.392, m grad 0.13, b grad -0.64
# Epoch 112, cost 0.388, m grad 0.129, b grad -0.637
# Epoch 113, cost 0.384, m grad 0.129, b grad -0.633
# Epoch 114, cost 0.379, m grad 0.128, b grad -0.629
# Epoch 115, cost 0.375, m grad 0.127, b grad -0.626
# Epoch 116, cost 0.371, m grad 0.127, b grad -0.622
# Epoch 117, cost 0.367, m grad 0.126, b grad -0.619
# Epoch 118, cost 0.363, m grad 0.125, b grad -0.615
# Epoch 119, cost 0.359, m grad 0.124, b grad -0.611
# Epoch 120, cost 0.355, m grad 0.124, b grad -0.608
# Epoch 121, cost 0.352, m grad 0.123, b grad -0.604
# Epoch 122, cost 0.348, m grad 0.122, b grad -0.601
# Epoch 123, cost 0.344, m grad 0.122, b grad -0.598
# Epoch 124, cost 0.34, m grad 0.121, b grad -0.594
# Epoch 125, cost 0.337, m grad 0.12, b grad -0.591
# Epoch 126, cost 0.333, m grad 0.119, b grad -0.587
# Epoch 127, cost 0.33, m grad 0.119, b grad -0.584
# Epoch 128, cost 0.326, m grad 0.118, b grad -0.58
# Epoch 129, cost 0.322, m grad 0.117, b grad -0.577
# Epoch 130, cost 0.319, m grad 0.117, b grad -0.574
# Epoch 131, cost 0.316, m grad 0.116, b grad -0.571
# Epoch 132, cost 0.312, m grad 0.115, b grad -0.567
# Epoch 133, cost 0.309, m grad 0.115, b grad -0.564
# Epoch 134, cost 0.306, m grad 0.114, b grad -0.561
# Epoch 135, cost 0.302, m grad 0.113, b grad -0.557
# Epoch 136, cost 0.299, m grad 0.113, b grad -0.554
# Epoch 137, cost 0.296, m grad 0.112, b grad -0.551
# Epoch 138, cost 0.293, m grad 0.111, b grad -0.548
# Epoch 139, cost 0.29, m grad 0.111, b grad -0.545
# Epoch 140, cost 0.287, m grad 0.11, b grad -0.542
# Epoch 141, cost 0.283, m grad 0.109, b grad -0.538
# Epoch 142, cost 0.28, m grad 0.109, b grad -0.535
# Epoch 143, cost 0.278, m grad 0.108, b grad -0.532
# Epoch 144, cost 0.275, m grad 0.108, b grad -0.529
# Epoch 145, cost 0.272, m grad 0.107, b grad -0.526
# Epoch 146, cost 0.269, m grad 0.106, b grad -0.523
# Epoch 147, cost 0.266, m grad 0.106, b grad -0.52
# Epoch 148, cost 0.263, m grad 0.105, b grad -0.517
# Epoch 149, cost 0.26, m grad 0.105, b grad -0.514
# Epoch 150, cost 0.258, m grad 0.104, b grad -0.511
# Epoch 151, cost 0.255, m grad 0.103, b grad -0.508
# Epoch 152, cost 0.252, m grad 0.103, b grad -0.505
# Epoch 153, cost 0.25, m grad 0.102, b grad -0.502
# Epoch 154, cost 0.247, m grad 0.102, b grad -0.499
# Epoch 155, cost 0.244, m grad 0.101, b grad -0.497
# Epoch 156, cost 0.242, m grad 0.1, b grad -0.494
# Epoch 157, cost 0.239, m grad 0.0998, b grad -0.491
# Epoch 158, cost 0.237, m grad 0.0992, b grad -0.488
# Epoch 159, cost 0.234, m grad 0.0987, b grad -0.485
# Epoch 160, cost 0.232, m grad 0.0981, b grad -0.482
# Epoch 161, cost 0.229, m grad 0.0975, b grad -0.48
# Epoch 162, cost 0.227, m grad 0.097, b grad -0.477
# Epoch 163, cost 0.225, m grad 0.0964, b grad -0.474
# Epoch 164, cost 0.222, m grad 0.0959, b grad -0.471
# Epoch 165, cost 0.22, m grad 0.0953, b grad -0.469
# Epoch 166, cost 0.218, m grad 0.0948, b grad -0.466
# Epoch 167, cost 0.215, m grad 0.0942, b grad -0.463
# Epoch 168, cost 0.213, m grad 0.0937, b grad -0.461
# Epoch 169, cost 0.211, m grad 0.0931, b grad -0.458
# Epoch 170, cost 0.209, m grad 0.0926, b grad -0.455
# Epoch 171, cost 0.207, m grad 0.0921, b grad -0.453
# Epoch 172, cost 0.205, m grad 0.0915, b grad -0.45
# Epoch 173, cost 0.203, m grad 0.091, b grad -0.447
# Epoch 174, cost 0.2, m grad 0.0905, b grad -0.445
# Epoch 175, cost 0.198, m grad 0.09, b grad -0.442
# Epoch 176, cost 0.196, m grad 0.0894, b grad -0.44
# Epoch 177, cost 0.194, m grad 0.0889, b grad -0.437
# Epoch 178, cost 0.192, m grad 0.0884, b grad -0.435
# Epoch 179, cost 0.19, m grad 0.0879, b grad -0.432
# Epoch 180, cost 0.188, m grad 0.0874, b grad -0.43
# Epoch 181, cost 0.187, m grad 0.0869, b grad -0.427
# Epoch 182, cost 0.185, m grad 0.0864, b grad -0.425
# Epoch 183, cost 0.183, m grad 0.0859, b grad -0.422
# Epoch 184, cost 0.181, m grad 0.0854, b grad -0.42
# Epoch 185, cost 0.179, m grad 0.0849, b grad -0.417
# Epoch 186, cost 0.177, m grad 0.0844, b grad -0.415
# Epoch 187, cost 0.175, m grad 0.0839, b grad -0.413
# Epoch 188, cost 0.174, m grad 0.0834, b grad -0.41
# Epoch 189, cost 0.172, m grad 0.083, b grad -0.408
# Epoch 190, cost 0.17, m grad 0.0825, b grad -0.406
# Epoch 191, cost 0.169, m grad 0.082, b grad -0.403
# Epoch 192, cost 0.167, m grad 0.0815, b grad -0.401
# Epoch 193, cost 0.165, m grad 0.0811, b grad -0.399
# Epoch 194, cost 0.164, m grad 0.0806, b grad -0.396
# Epoch 195, cost 0.162, m grad 0.0801, b grad -0.394
# Epoch 196, cost 0.16, m grad 0.0797, b grad -0.392
# Epoch 197, cost 0.159, m grad 0.0792, b grad -0.39
# Epoch 198, cost 0.157, m grad 0.0788, b grad -0.387
# Epoch 199, cost 0.156, m grad 0.0783, b grad -0.385
# Epoch 200, cost 0.154, m grad 0.0778, b grad -0.383
# Epoch 201, cost 0.152, m grad 0.0774, b grad -0.381
# Epoch 202, cost 0.151, m grad 0.077, b grad -0.378
# Epoch 203, cost 0.149, m grad 0.0765, b grad -0.376
# Epoch 204, cost 0.148, m grad 0.0761, b grad -0.374
# Epoch 205, cost 0.147, m grad 0.0756, b grad -0.372
# Epoch 206, cost 0.145, m grad 0.0752, b grad -0.37
# Epoch 207, cost 0.144, m grad 0.0748, b grad -0.368
# Epoch 208, cost 0.142, m grad 0.0743, b grad -0.366
# Epoch 209, cost 0.141, m grad 0.0739, b grad -0.363
# Epoch 210, cost 0.14, m grad 0.0735, b grad -0.361
# Epoch 211, cost 0.138, m grad 0.073, b grad -0.359
# Epoch 212, cost 0.137, m grad 0.0726, b grad -0.357
# Epoch 213, cost 0.136, m grad 0.0722, b grad -0.355
# Epoch 214, cost 0.134, m grad 0.0718, b grad -0.353
# Epoch 215, cost 0.133, m grad 0.0714, b grad -0.351
# Epoch 216, cost 0.132, m grad 0.071, b grad -0.349
# Epoch 217, cost 0.13, m grad 0.0706, b grad -0.347
# Epoch 218, cost 0.129, m grad 0.0702, b grad -0.345
# Epoch 219, cost 0.128, m grad 0.0697, b grad -0.343
# Epoch 220, cost 0.127, m grad 0.0693, b grad -0.341
# Epoch 221, cost 0.125, m grad 0.0689, b grad -0.339
# Epoch 222, cost 0.124, m grad 0.0685, b grad -0.337
# Epoch 223, cost 0.123, m grad 0.0682, b grad -0.335
# Epoch 224, cost 0.122, m grad 0.0678, b grad -0.333
# Epoch 225, cost 0.121, m grad 0.0674, b grad -0.331
# Epoch 226, cost 0.12, m grad 0.067, b grad -0.329
# Epoch 227, cost 0.119, m grad 0.0666, b grad -0.327
# Epoch 228, cost 0.117, m grad 0.0662, b grad -0.326
# Epoch 229, cost 0.116, m grad 0.0658, b grad -0.324
# Epoch 230, cost 0.115, m grad 0.0654, b grad -0.322
# Epoch 231, cost 0.114, m grad 0.0651, b grad -0.32
# Epoch 232, cost 0.113, m grad 0.0647, b grad -0.318
# Epoch 233, cost 0.112, m grad 0.0643, b grad -0.316
# Epoch 234, cost 0.111, m grad 0.064, b grad -0.314
# Epoch 235, cost 0.11, m grad 0.0636, b grad -0.313
# Epoch 236, cost 0.109, m grad 0.0632, b grad -0.311
# Epoch 237, cost 0.108, m grad 0.0629, b grad -0.309
# Epoch 238, cost 0.107, m grad 0.0625, b grad -0.307
# Epoch 239, cost 0.106, m grad 0.0621, b grad -0.306
# Epoch 240, cost 0.105, m grad 0.0618, b grad -0.304
# Epoch 241, cost 0.104, m grad 0.0614, b grad -0.302
# Epoch 242, cost 0.103, m grad 0.0611, b grad -0.3
# Epoch 243, cost 0.102, m grad 0.0607, b grad -0.299
# Epoch 244, cost 0.101, m grad 0.0604, b grad -0.297
# Epoch 245, cost 0.1, m grad 0.06, b grad -0.295
# Epoch 246, cost 0.0994, m grad 0.0597, b grad -0.293
# Epoch 247, cost 0.0985, m grad 0.0593, b grad -0.292
# Epoch 248, cost 0.0976, m grad 0.059, b grad -0.29
# Epoch 249, cost 0.0968, m grad 0.0586, b grad -0.288
# Epoch 250, cost 0.0959, m grad 0.0583, b grad -0.287
# Epoch 251, cost 0.095, m grad 0.058, b grad -0.285
# Epoch 252, cost 0.0942, m grad 0.0576, b grad -0.283
# Epoch 253, cost 0.0934, m grad 0.0573, b grad -0.282
# Epoch 254, cost 0.0925, m grad 0.057, b grad -0.28
# Epoch 255, cost 0.0917, m grad 0.0566, b grad -0.279
# Epoch 256, cost 0.0909, m grad 0.0563, b grad -0.277
# Epoch 257, cost 0.0901, m grad 0.056, b grad -0.275
# Epoch 258, cost 0.0893, m grad 0.0557, b grad -0.274
# Epoch 259, cost 0.0886, m grad 0.0553, b grad -0.272
# Epoch 260, cost 0.0878, m grad 0.055, b grad -0.271
# Epoch 261, cost 0.087, m grad 0.0547, b grad -0.269
# Epoch 262, cost 0.0863, m grad 0.0544, b grad -0.267
# Epoch 263, cost 0.0855, m grad 0.0541, b grad -0.266
# Epoch 264, cost 0.0848, m grad 0.0538, b grad -0.264
# Epoch 265, cost 0.0841, m grad 0.0535, b grad -0.263
# Epoch 266, cost 0.0834, m grad 0.0531, b grad -0.261
# Epoch 267, cost 0.0826, m grad 0.0528, b grad -0.26
# Epoch 268, cost 0.0819, m grad 0.0525, b grad -0.258
# Epoch 269, cost 0.0812, m grad 0.0522, b grad -0.257
# Epoch 270, cost 0.0806, m grad 0.0519, b grad -0.255
# Epoch 271, cost 0.0799, m grad 0.0516, b grad -0.254
# Epoch 272, cost 0.0792, m grad 0.0513, b grad -0.252
# Epoch 273, cost 0.0786, m grad 0.051, b grad -0.251
# Epoch 274, cost 0.0779, m grad 0.0507, b grad -0.25
# Epoch 275, cost 0.0773, m grad 0.0505, b grad -0.248
# Epoch 276, cost 0.0766, m grad 0.0502, b grad -0.247
# Epoch 277, cost 0.076, m grad 0.0499, b grad -0.245
# Epoch 278, cost 0.0754, m grad 0.0496, b grad -0.244
# Epoch 279, cost 0.0747, m grad 0.0493, b grad -0.242
# Epoch 280, cost 0.0741, m grad 0.049, b grad -0.241
# Epoch 281, cost 0.0735, m grad 0.0487, b grad -0.24
# Epoch 282, cost 0.0729, m grad 0.0485, b grad -0.238
# Epoch 283, cost 0.0723, m grad 0.0482, b grad -0.237
# Epoch 284, cost 0.0718, m grad 0.0479, b grad -0.236
# Epoch 285, cost 0.0712, m grad 0.0476, b grad -0.234
# Epoch 286, cost 0.0706, m grad 0.0473, b grad -0.233
# Epoch 287, cost 0.07, m grad 0.0471, b grad -0.231
# Epoch 288, cost 0.0695, m grad 0.0468, b grad -0.23
# Epoch 289, cost 0.0689, m grad 0.0465, b grad -0.229
# Epoch 290, cost 0.0684, m grad 0.0463, b grad -0.227
# Epoch 291, cost 0.0679, m grad 0.046, b grad -0.226
# Epoch 292, cost 0.0673, m grad 0.0457, b grad -0.225
# Epoch 293, cost 0.0668, m grad 0.0455, b grad -0.224
# Epoch 294, cost 0.0663, m grad 0.0452, b grad -0.222
# Epoch 295, cost 0.0658, m grad 0.0449, b grad -0.221
# Epoch 296, cost 0.0653, m grad 0.0447, b grad -0.22
# Epoch 297, cost 0.0648, m grad 0.0444, b grad -0.218
# Epoch 298, cost 0.0643, m grad 0.0442, b grad -0.217
# Epoch 299, cost 0.0638, m grad 0.0439, b grad -0.216
# Epoch 300, cost 0.0633, m grad 0.0437, b grad -0.215
# Epoch 301, cost 0.0628, m grad 0.0434, b grad -0.213
# Epoch 302, cost 0.0623, m grad 0.0432, b grad -0.212
# Epoch 303, cost 0.0619, m grad 0.0429, b grad -0.211
# Epoch 304, cost 0.0614, m grad 0.0427, b grad -0.21
# Epoch 305, cost 0.061, m grad 0.0424, b grad -0.209
# Epoch 306, cost 0.0605, m grad 0.0422, b grad -0.207
# Epoch 307, cost 0.0601, m grad 0.0419, b grad -0.206
# Epoch 308, cost 0.0596, m grad 0.0417, b grad -0.205
# Epoch 309, cost 0.0592, m grad 0.0414, b grad -0.204
# Epoch 310, cost 0.0587, m grad 0.0412, b grad -0.203
# Epoch 311, cost 0.0583, m grad 0.041, b grad -0.201
# Epoch 312, cost 0.0579, m grad 0.0407, b grad -0.2
# Epoch 313, cost 0.0575, m grad 0.0405, b grad -0.199
# Epoch 314, cost 0.0571, m grad 0.0403, b grad -0.198
# Epoch 315, cost 0.0567, m grad 0.04, b grad -0.197
# Epoch 316, cost 0.0563, m grad 0.0398, b grad -0.196
# Epoch 317, cost 0.0559, m grad 0.0396, b grad -0.195
# Epoch 318, cost 0.0555, m grad 0.0393, b grad -0.193
# Epoch 319, cost 0.0551, m grad 0.0391, b grad -0.192
# Epoch 320, cost 0.0547, m grad 0.0389, b grad -0.191
# Epoch 321, cost 0.0543, m grad 0.0387, b grad -0.19
# Epoch 322, cost 0.0539, m grad 0.0384, b grad -0.189
# Epoch 323, cost 0.0536, m grad 0.0382, b grad -0.188
# Epoch 324, cost 0.0532, m grad 0.038, b grad -0.187
# Epoch 325, cost 0.0528, m grad 0.0378, b grad -0.186
# Epoch 326, cost 0.0525, m grad 0.0376, b grad -0.185
# Epoch 327, cost 0.0521, m grad 0.0374, b grad -0.184
# Epoch 328, cost 0.0518, m grad 0.0371, b grad -0.183
# Epoch 329, cost 0.0514, m grad 0.0369, b grad -0.182
# Epoch 330, cost 0.0511, m grad 0.0367, b grad -0.181
# Epoch 331, cost 0.0508, m grad 0.0365, b grad -0.179
# Epoch 332, cost 0.0504, m grad 0.0363, b grad -0.178
# Epoch 333, cost 0.0501, m grad 0.0361, b grad -0.177
# Epoch 334, cost 0.0498, m grad 0.0359, b grad -0.176
# Epoch 335, cost 0.0494, m grad 0.0357, b grad -0.175
# Epoch 336, cost 0.0491, m grad 0.0355, b grad -0.174
# Epoch 337, cost 0.0488, m grad 0.0353, b grad -0.173
# Epoch 338, cost 0.0485, m grad 0.0351, b grad -0.172
# Epoch 339, cost 0.0482, m grad 0.0348, b grad -0.171
# Epoch 340, cost 0.0479, m grad 0.0346, b grad -0.17
# Epoch 341, cost 0.0476, m grad 0.0344, b grad -0.169
# Epoch 342, cost 0.0473, m grad 0.0342, b grad -0.168
# Epoch 343, cost 0.047, m grad 0.034, b grad -0.167
# Epoch 344, cost 0.0467, m grad 0.0339, b grad -0.166
# Epoch 345, cost 0.0464, m grad 0.0337, b grad -0.166
# Epoch 346, cost 0.0461, m grad 0.0335, b grad -0.165
# Epoch 347, cost 0.0458, m grad 0.0333, b grad -0.164
# Epoch 348, cost 0.0456, m grad 0.0331, b grad -0.163
# Epoch 349, cost 0.0453, m grad 0.0329, b grad -0.162
# Epoch 350, cost 0.045, m grad 0.0327, b grad -0.161
# Epoch 351, cost 0.0447, m grad 0.0325, b grad -0.16
# Epoch 352, cost 0.0445, m grad 0.0323, b grad -0.159
# Epoch 353, cost 0.0442, m grad 0.0321, b grad -0.158
# Epoch 354, cost 0.044, m grad 0.032, b grad -0.157
# Epoch 355, cost 0.0437, m grad 0.0318, b grad -0.156
# Epoch 356, cost 0.0434, m grad 0.0316, b grad -0.155
# Epoch 357, cost 0.0432, m grad 0.0314, b grad -0.154
# Epoch 358, cost 0.0429, m grad 0.0312, b grad -0.154
# Epoch 359, cost 0.0427, m grad 0.031, b grad -0.153
# Epoch 360, cost 0.0425, m grad 0.0309, b grad -0.152
# Epoch 361, cost 0.0422, m grad 0.0307, b grad -0.151
# Epoch 362, cost 0.042, m grad 0.0305, b grad -0.15
# Epoch 363, cost 0.0418, m grad 0.0303, b grad -0.149
# Epoch 364, cost 0.0415, m grad 0.0302, b grad -0.148
# Epoch 365, cost 0.0413, m grad 0.03, b grad -0.147
# Epoch 366, cost 0.0411, m grad 0.0298, b grad -0.147
# Epoch 367, cost 0.0408, m grad 0.0296, b grad -0.146
# Epoch 368, cost 0.0406, m grad 0.0295, b grad -0.145
# Epoch 369, cost 0.0404, m grad 0.0293, b grad -0.144
# Epoch 370, cost 0.0402, m grad 0.0291, b grad -0.143
# Epoch 371, cost 0.04, m grad 0.029, b grad -0.142
# Epoch 372, cost 0.0398, m grad 0.0288, b grad -0.142
# Epoch 373, cost 0.0396, m grad 0.0286, b grad -0.141
# Epoch 374, cost 0.0394, m grad 0.0285, b grad -0.14
# Epoch 375, cost 0.0391, m grad 0.0283, b grad -0.139
# Epoch 376, cost 0.0389, m grad 0.0281, b grad -0.138
# Epoch 377, cost 0.0387, m grad 0.028, b grad -0.138
# Epoch 378, cost 0.0386, m grad 0.0278, b grad -0.137
# Epoch 379, cost 0.0384, m grad 0.0277, b grad -0.136
# Epoch 380, cost 0.0382, m grad 0.0275, b grad -0.135
# Epoch 381, cost 0.038, m grad 0.0273, b grad -0.134
# Epoch 382, cost 0.0378, m grad 0.0272, b grad -0.134
# Epoch 383, cost 0.0376, m grad 0.027, b grad -0.133
# Epoch 384, cost 0.0374, m grad 0.0269, b grad -0.132
# Epoch 385, cost 0.0372, m grad 0.0267, b grad -0.131
# Epoch 386, cost 0.0371, m grad 0.0266, b grad -0.131
# Epoch 387, cost 0.0369, m grad 0.0264, b grad -0.13
# Epoch 388, cost 0.0367, m grad 0.0263, b grad -0.129
# Epoch 389, cost 0.0365, m grad 0.0261, b grad -0.128
# Epoch 390, cost 0.0364, m grad 0.0259, b grad -0.128
# Epoch 391, cost 0.0362, m grad 0.0258, b grad -0.127
# Epoch 392, cost 0.036, m grad 0.0256, b grad -0.126
# Epoch 393, cost 0.0359, m grad 0.0255, b grad -0.125
# Epoch 394, cost 0.0357, m grad 0.0254, b grad -0.125
# Epoch 395, cost 0.0355, m grad 0.0252, b grad -0.124
# Epoch 396, cost 0.0354, m grad 0.0251, b grad -0.123
# Epoch 397, cost 0.0352, m grad 0.0249, b grad -0.123
# Epoch 398, cost 0.0351, m grad 0.0248, b grad -0.122
# Epoch 399, cost 0.0349, m grad 0.0246, b grad -0.121
# Epoch 400, cost 0.0348, m grad 0.0245, b grad -0.12
# Epoch 401, cost 0.0346, m grad 0.0243, b grad -0.12
# Epoch 402, cost 0.0345, m grad 0.0242, b grad -0.119
# Epoch 403, cost 0.0343, m grad 0.0241, b grad -0.118
# Epoch 404, cost 0.0342, m grad 0.0239, b grad -0.118
# Epoch 405, cost 0.034, m grad 0.0238, b grad -0.117
# Epoch 406, cost 0.0339, m grad 0.0237, b grad -0.116
# Epoch 407, cost 0.0337, m grad 0.0235, b grad -0.116
# Epoch 408, cost 0.0336, m grad 0.0234, b grad -0.115
# Epoch 409, cost 0.0335, m grad 0.0232, b grad -0.114
# Epoch 410, cost 0.0333, m grad 0.0231, b grad -0.114
# Epoch 411, cost 0.0332, m grad 0.023, b grad -0.113
# Epoch 412, cost 0.0331, m grad 0.0228, b grad -0.112
# Epoch 413, cost 0.0329, m grad 0.0227, b grad -0.112
# Epoch 414, cost 0.0328, m grad 0.0226, b grad -0.111
# Epoch 415, cost 0.0327, m grad 0.0225, b grad -0.11
# Epoch 416, cost 0.0325, m grad 0.0223, b grad -0.11
# Epoch 417, cost 0.0324, m grad 0.0222, b grad -0.109
# Epoch 418, cost 0.0323, m grad 0.0221, b grad -0.109
# Epoch 419, cost 0.0322, m grad 0.0219, b grad -0.108
# Epoch 420, cost 0.0321, m grad 0.0218, b grad -0.107
# Epoch 421, cost 0.0319, m grad 0.0217, b grad -0.107
# Epoch 422, cost 0.0318, m grad 0.0216, b grad -0.106
# Epoch 423, cost 0.0317, m grad 0.0214, b grad -0.105
# Epoch 424, cost 0.0316, m grad 0.0213, b grad -0.105
# Epoch 425, cost 0.0315, m grad 0.0212, b grad -0.104
# Epoch 426, cost 0.0314, m grad 0.0211, b grad -0.104
# Epoch 427, cost 0.0312, m grad 0.021, b grad -0.103
# Epoch 428, cost 0.0311, m grad 0.0208, b grad -0.102
# Epoch 429, cost 0.031, m grad 0.0207, b grad -0.102
# Epoch 430, cost 0.0309, m grad 0.0206, b grad -0.101
# Epoch 431, cost 0.0308, m grad 0.0205, b grad -0.101
# Epoch 432, cost 0.0307, m grad 0.0204, b grad -0.1
# Epoch 433, cost 0.0306, m grad 0.0202, b grad -0.0995
# Epoch 434, cost 0.0305, m grad 0.0201, b grad -0.0989
# Epoch 435, cost 0.0304, m grad 0.02, b grad -0.0984
# Epoch 436, cost 0.0303, m grad 0.0199, b grad -0.0978
# Epoch 437, cost 0.0302, m grad 0.0198, b grad -0.0972
# Epoch 438, cost 0.0301, m grad 0.0197, b grad -0.0967
# Epoch 439, cost 0.03, m grad 0.0195, b grad -0.0961
# Epoch 440, cost 0.0299, m grad 0.0194, b grad -0.0956
# Epoch 441, cost 0.0298, m grad 0.0193, b grad -0.095
# Epoch 442, cost 0.0297, m grad 0.0192, b grad -0.0945
# Epoch 443, cost 0.0296, m grad 0.0191, b grad -0.0939
# Epoch 444, cost 0.0295, m grad 0.019, b grad -0.0934
# Epoch 445, cost 0.0294, m grad 0.0189, b grad -0.0928
# Epoch 446, cost 0.0294, m grad 0.0188, b grad -0.0923
# Epoch 447, cost 0.0293, m grad 0.0187, b grad -0.0918
# Epoch 448, cost 0.0292, m grad 0.0186, b grad -0.0912
# Epoch 449, cost 0.0291, m grad 0.0184, b grad -0.0907
# Epoch 450, cost 0.029, m grad 0.0183, b grad -0.0902
# Epoch 451, cost 0.0289, m grad 0.0182, b grad -0.0897
# Epoch 452, cost 0.0288, m grad 0.0181, b grad -0.0892
# Epoch 453, cost 0.0288, m grad 0.018, b grad -0.0886
# Epoch 454, cost 0.0287, m grad 0.0179, b grad -0.0881
# Epoch 455, cost 0.0286, m grad 0.0178, b grad -0.0876
# Epoch 456, cost 0.0285, m grad 0.0177, b grad -0.0871
# Epoch 457, cost 0.0284, m grad 0.0176, b grad -0.0866
# Epoch 458, cost 0.0284, m grad 0.0175, b grad -0.0861
# Epoch 459, cost 0.0283, m grad 0.0174, b grad -0.0856
# Epoch 460, cost 0.0282, m grad 0.0173, b grad -0.0851
# Epoch 461, cost 0.0281, m grad 0.0172, b grad -0.0846
# Epoch 462, cost 0.0281, m grad 0.0171, b grad -0.0842
# Epoch 463, cost 0.028, m grad 0.017, b grad -0.0837
# Epoch 464, cost 0.0279, m grad 0.0169, b grad -0.0832
# Epoch 465, cost 0.0278, m grad 0.0168, b grad -0.0827
# Epoch 466, cost 0.0278, m grad 0.0167, b grad -0.0822
# Epoch 467, cost 0.0277, m grad 0.0166, b grad -0.0818
# Epoch 468, cost 0.0276, m grad 0.0165, b grad -0.0813
# Epoch 469, cost 0.0276, m grad 0.0164, b grad -0.0808
# Epoch 470, cost 0.0275, m grad 0.0163, b grad -0.0803
# Epoch 471, cost 0.0274, m grad 0.0162, b grad -0.0799
# Epoch 472, cost 0.0274, m grad 0.0162, b grad -0.0794
# Epoch 473, cost 0.0273, m grad 0.0161, b grad -0.079
# Epoch 474, cost 0.0272, m grad 0.016, b grad -0.0785
# Epoch 475, cost 0.0272, m grad 0.0159, b grad -0.0781
# Epoch 476, cost 0.0271, m grad 0.0158, b grad -0.0776
# Epoch 477, cost 0.027, m grad 0.0157, b grad -0.0772
# Epoch 478, cost 0.027, m grad 0.0156, b grad -0.0767
# Epoch 479, cost 0.0269, m grad 0.0155, b grad -0.0763
# Epoch 480, cost 0.0269, m grad 0.0154, b grad -0.0758
# Epoch 481, cost 0.0268, m grad 0.0153, b grad -0.0754
# Epoch 482, cost 0.0267, m grad 0.0152, b grad -0.075
# Epoch 483, cost 0.0267, m grad 0.0152, b grad -0.0745
# Epoch 484, cost 0.0266, m grad 0.0151, b grad -0.0741
# Epoch 485, cost 0.0266, m grad 0.015, b grad -0.0737
# Epoch 486, cost 0.0265, m grad 0.0149, b grad -0.0732
# Epoch 487, cost 0.0264, m grad 0.0148, b grad -0.0728
# Epoch 488, cost 0.0264, m grad 0.0147, b grad -0.0724
# Epoch 489, cost 0.0263, m grad 0.0146, b grad -0.072
# Epoch 490, cost 0.0263, m grad 0.0146, b grad -0.0716
# Epoch 491, cost 0.0262, m grad 0.0145, b grad -0.0712
# Epoch 492, cost 0.0262, m grad 0.0144, b grad -0.0707
# Epoch 493, cost 0.0261, m grad 0.0143, b grad -0.0703
# Epoch 494, cost 0.0261, m grad 0.0142, b grad -0.0699
# Epoch 495, cost 0.026, m grad 0.0141, b grad -0.0695
# Epoch 496, cost 0.026, m grad 0.0141, b grad -0.0691
# Epoch 497, cost 0.0259, m grad 0.014, b grad -0.0687
# Epoch 498, cost 0.0259, m grad 0.0139, b grad -0.0683
# Epoch 499, cost 0.0258, m grad 0.0138, b grad -0.0679
# Epoch 500, cost 0.0258, m grad 0.0137, b grad -0.0676
# Epoch 501, cost 0.0257, m grad 0.0137, b grad -0.0672
# Epoch 502, cost 0.0257, m grad 0.0136, b grad -0.0668
# Epoch 503, cost 0.0256, m grad 0.0135, b grad -0.0664
# Epoch 504, cost 0.0256, m grad 0.0134, b grad -0.066
# Epoch 505, cost 0.0255, m grad 0.0133, b grad -0.0656
# Epoch 506, cost 0.0255, m grad 0.0133, b grad -0.0652
# Epoch 507, cost 0.0255, m grad 0.0132, b grad -0.0649
# Epoch 508, cost 0.0254, m grad 0.0131, b grad -0.0645
# Epoch 509, cost 0.0254, m grad 0.013, b grad -0.0641
# Epoch 510, cost 0.0253, m grad 0.013, b grad -0.0638
# Epoch 511, cost 0.0253, m grad 0.0129, b grad -0.0634
# Epoch 512, cost 0.0252, m grad 0.0128, b grad -0.063
# Epoch 513, cost 0.0252, m grad 0.0127, b grad -0.0627
# Epoch 514, cost 0.0252, m grad 0.0127, b grad -0.0623
# Epoch 515, cost 0.0251, m grad 0.0126, b grad -0.0619
# Epoch 516, cost 0.0251, m grad 0.0125, b grad -0.0616
# Epoch 517, cost 0.025, m grad 0.0125, b grad -0.0612
# Epoch 518, cost 0.025, m grad 0.0124, b grad -0.0609
# Epoch 519, cost 0.025, m grad 0.0123, b grad -0.0605
# Epoch 520, cost 0.0249, m grad 0.0122, b grad -0.0602
# Epoch 521, cost 0.0249, m grad 0.0122, b grad -0.0598
# Epoch 522, cost 0.0249, m grad 0.0121, b grad -0.0595
# Epoch 523, cost 0.0248, m grad 0.012, b grad -0.0591
# Epoch 524, cost 0.0248, m grad 0.012, b grad -0.0588
# Epoch 525, cost 0.0247, m grad 0.0119, b grad -0.0585
# Epoch 526, cost 0.0247, m grad 0.0118, b grad -0.0581
# Epoch 527, cost 0.0247, m grad 0.0118, b grad -0.0578
# Epoch 528, cost 0.0246, m grad 0.0117, b grad -0.0575
# Epoch 529, cost 0.0246, m grad 0.0116, b grad -0.0571
# Epoch 530, cost 0.0246, m grad 0.0115, b grad -0.0568
# Epoch 531, cost 0.0245, m grad 0.0115, b grad -0.0565
# Epoch 532, cost 0.0245, m grad 0.0114, b grad -0.0561
# Epoch 533, cost 0.0245, m grad 0.0114, b grad -0.0558
# Epoch 534, cost 0.0244, m grad 0.0113, b grad -0.0555
# Epoch 535, cost 0.0244, m grad 0.0112, b grad -0.0552
# Epoch 536, cost 0.0244, m grad 0.0112, b grad -0.0549
# Epoch 537, cost 0.0243, m grad 0.0111, b grad -0.0545
# Epoch 538, cost 0.0243, m grad 0.011, b grad -0.0542
# Epoch 539, cost 0.0243, m grad 0.011, b grad -0.0539
# Epoch 540, cost 0.0243, m grad 0.0109, b grad -0.0536
# Epoch 541, cost 0.0242, m grad 0.0108, b grad -0.0533
# Epoch 542, cost 0.0242, m grad 0.0108, b grad -0.053
# Epoch 543, cost 0.0242, m grad 0.0107, b grad -0.0527
# Epoch 544, cost 0.0241, m grad 0.0107, b grad -0.0524
# Epoch 545, cost 0.0241, m grad 0.0106, b grad -0.0521
# Epoch 546, cost 0.0241, m grad 0.0105, b grad -0.0518
# Epoch 547, cost 0.0241, m grad 0.0105, b grad -0.0515
# Epoch 548, cost 0.024, m grad 0.0104, b grad -0.0512
# Epoch 549, cost 0.024, m grad 0.0103, b grad -0.0509
# Epoch 550, cost 0.024, m grad 0.0103, b grad -0.0506
# Epoch 551, cost 0.0239, m grad 0.0102, b grad -0.0503
# Epoch 552, cost 0.0239, m grad 0.0102, b grad -0.05
# Epoch 553, cost 0.0239, m grad 0.0101, b grad -0.0497
# Epoch 554, cost 0.0239, m grad 0.0101, b grad -0.0494
# Epoch 555, cost 0.0238, m grad 0.00999, b grad -0.0491
# Epoch 556, cost 0.0238, m grad 0.00994, b grad -0.0489
# Epoch 557, cost 0.0238, m grad 0.00988, b grad -0.0486
# Epoch 558, cost 0.0238, m grad 0.00982, b grad -0.0483
# Epoch 559, cost 0.0237, m grad 0.00977, b grad -0.048
# Epoch 560, cost 0.0237, m grad 0.00971, b grad -0.0477
# Epoch 561, cost 0.0237, m grad 0.00965, b grad -0.0475
# Epoch 562, cost 0.0237, m grad 0.0096, b grad -0.0472
# Epoch 563, cost 0.0236, m grad 0.00954, b grad -0.0469
# Epoch 564, cost 0.0236, m grad 0.00949, b grad -0.0467
# Epoch 565, cost 0.0236, m grad 0.00943, b grad -0.0464
# Epoch 566, cost 0.0236, m grad 0.00938, b grad -0.0461
# Epoch 567, cost 0.0236, m grad 0.00932, b grad -0.0459
# Epoch 568, cost 0.0235, m grad 0.00927, b grad -0.0456
# Epoch 569, cost 0.0235, m grad 0.00922, b grad -0.0453
# Epoch 570, cost 0.0235, m grad 0.00916, b grad -0.0451
# Epoch 571, cost 0.0235, m grad 0.00911, b grad -0.0448
# Epoch 572, cost 0.0235, m grad 0.00906, b grad -0.0445
# Epoch 573, cost 0.0234, m grad 0.00901, b grad -0.0443
# Epoch 574, cost 0.0234, m grad 0.00895, b grad -0.044
# Epoch 575, cost 0.0234, m grad 0.0089, b grad -0.0438
# Epoch 576, cost 0.0234, m grad 0.00885, b grad -0.0435
# Epoch 577, cost 0.0234, m grad 0.0088, b grad -0.0433
# Epoch 578, cost 0.0233, m grad 0.00875, b grad -0.043
# Epoch 579, cost 0.0233, m grad 0.0087, b grad -0.0428
# Epoch 580, cost 0.0233, m grad 0.00865, b grad -0.0425
# Epoch 581, cost 0.0233, m grad 0.0086, b grad -0.0423
# Epoch 582, cost 0.0233, m grad 0.00855, b grad -0.042
# Epoch 583, cost 0.0232, m grad 0.0085, b grad -0.0418
# Epoch 584, cost 0.0232, m grad 0.00845, b grad -0.0416
# Epoch 585, cost 0.0232, m grad 0.0084, b grad -0.0413
# Epoch 586, cost 0.0232, m grad 0.00835, b grad -0.0411
# Epoch 587, cost 0.0232, m grad 0.00831, b grad -0.0408
# Epoch 588, cost 0.0231, m grad 0.00826, b grad -0.0406
# Epoch 589, cost 0.0231, m grad 0.00821, b grad -0.0404
# Epoch 590, cost 0.0231, m grad 0.00816, b grad -0.0401
# Epoch 591, cost 0.0231, m grad 0.00812, b grad -0.0399
# Epoch 592, cost 0.0231, m grad 0.00807, b grad -0.0397
# Epoch 593, cost 0.0231, m grad 0.00802, b grad -0.0395
# Epoch 594, cost 0.023, m grad 0.00798, b grad -0.0392
# Epoch 595, cost 0.023, m grad 0.00793, b grad -0.039
# Epoch 596, cost 0.023, m grad 0.00789, b grad -0.0388
# Epoch 597, cost 0.023, m grad 0.00784, b grad -0.0386
# Epoch 598, cost 0.023, m grad 0.00779, b grad -0.0383
# Epoch 599, cost 0.023, m grad 0.00775, b grad -0.0381
# Epoch 600, cost 0.023, m grad 0.0077, b grad -0.0379
# Epoch 601, cost 0.0229, m grad 0.00766, b grad -0.0377
# Epoch 602, cost 0.0229, m grad 0.00762, b grad -0.0375
# Epoch 603, cost 0.0229, m grad 0.00757, b grad -0.0372
# Epoch 604, cost 0.0229, m grad 0.00753, b grad -0.037
# Epoch 605, cost 0.0229, m grad 0.00749, b grad -0.0368
# Epoch 606, cost 0.0229, m grad 0.00744, b grad -0.0366
# Epoch 607, cost 0.0229, m grad 0.0074, b grad -0.0364
# Epoch 608, cost 0.0228, m grad 0.00736, b grad -0.0362
# Epoch 609, cost 0.0228, m grad 0.00731, b grad -0.036
# Epoch 610, cost 0.0228, m grad 0.00727, b grad -0.0358
# Epoch 611, cost 0.0228, m grad 0.00723, b grad -0.0356
# Epoch 612, cost 0.0228, m grad 0.00719, b grad -0.0353
# Epoch 613, cost 0.0228, m grad 0.00715, b grad -0.0351
# Epoch 614, cost 0.0228, m grad 0.00711, b grad -0.0349
# Epoch 615, cost 0.0227, m grad 0.00707, b grad -0.0347
# Epoch 616, cost 0.0227, m grad 0.00702, b grad -0.0345
# Epoch 617, cost 0.0227, m grad 0.00698, b grad -0.0343
# Epoch 618, cost 0.0227, m grad 0.00694, b grad -0.0341
# Epoch 619, cost 0.0227, m grad 0.0069, b grad -0.0339
# Epoch 620, cost 0.0227, m grad 0.00686, b grad -0.0338
# Epoch 621, cost 0.0227, m grad 0.00682, b grad -0.0336
# Epoch 622, cost 0.0227, m grad 0.00678, b grad -0.0334
# Epoch 623, cost 0.0227, m grad 0.00675, b grad -0.0332
# Epoch 624, cost 0.0226, m grad 0.00671, b grad -0.033
# Epoch 625, cost 0.0226, m grad 0.00667, b grad -0.0328
# Epoch 626, cost 0.0226, m grad 0.00663, b grad -0.0326
# Epoch 627, cost 0.0226, m grad 0.00659, b grad -0.0324
# Epoch 628, cost 0.0226, m grad 0.00655, b grad -0.0322
# Epoch 629, cost 0.0226, m grad 0.00652, b grad -0.032
# Epoch 630, cost 0.0226, m grad 0.00648, b grad -0.0319
# Epoch 631, cost 0.0226, m grad 0.00644, b grad -0.0317
# Epoch 632, cost 0.0226, m grad 0.0064, b grad -0.0315
# Epoch 633, cost 0.0225, m grad 0.00637, b grad -0.0313
# Epoch 634, cost 0.0225, m grad 0.00633, b grad -0.0311
# Epoch 635, cost 0.0225, m grad 0.00629, b grad -0.0309
# Epoch 636, cost 0.0225, m grad 0.00626, b grad -0.0308
# Epoch 637, cost 0.0225, m grad 0.00622, b grad -0.0306
# Epoch 638, cost 0.0225, m grad 0.00618, b grad -0.0304
# Epoch 639, cost 0.0225, m grad 0.00615, b grad -0.0302
# Epoch 640, cost 0.0225, m grad 0.00611, b grad -0.0301
# Epoch 641, cost 0.0225, m grad 0.00608, b grad -0.0299
# Epoch 642, cost 0.0225, m grad 0.00604, b grad -0.0297
# Epoch 643, cost 0.0224, m grad 0.00601, b grad -0.0295
# Epoch 644, cost 0.0224, m grad 0.00597, b grad -0.0294
# Epoch 645, cost 0.0224, m grad 0.00594, b grad -0.0292
# Epoch 646, cost 0.0224, m grad 0.00591, b grad -0.029
# Epoch 647, cost 0.0224, m grad 0.00587, b grad -0.0289
# Epoch 648, cost 0.0224, m grad 0.00584, b grad -0.0287
# Epoch 649, cost 0.0224, m grad 0.0058, b grad -0.0285
# Epoch 650, cost 0.0224, m grad 0.00577, b grad -0.0284
# Epoch 651, cost 0.0224, m grad 0.00574, b grad -0.0282
# Epoch 652, cost 0.0224, m grad 0.0057, b grad -0.028
# Epoch 653, cost 0.0224, m grad 0.00567, b grad -0.0279
# Epoch 654, cost 0.0224, m grad 0.00564, b grad -0.0277
# Epoch 655, cost 0.0223, m grad 0.00561, b grad -0.0276
# Epoch 656, cost 0.0223, m grad 0.00557, b grad -0.0274
# Epoch 657, cost 0.0223, m grad 0.00554, b grad -0.0273
# Epoch 658, cost 0.0223, m grad 0.00551, b grad -0.0271
# Epoch 659, cost 0.0223, m grad 0.00548, b grad -0.0269
# Epoch 660, cost 0.0223, m grad 0.00545, b grad -0.0268
# Epoch 661, cost 0.0223, m grad 0.00542, b grad -0.0266
# Epoch 662, cost 0.0223, m grad 0.00538, b grad -0.0265
# Epoch 663, cost 0.0223, m grad 0.00535, b grad -0.0263
# Epoch 664, cost 0.0223, m grad 0.00532, b grad -0.0262
# Epoch 665, cost 0.0223, m grad 0.00529, b grad -0.026
# Epoch 666, cost 0.0223, m grad 0.00526, b grad -0.0259
# Epoch 667, cost 0.0223, m grad 0.00523, b grad -0.0257
# Epoch 668, cost 0.0222, m grad 0.0052, b grad -0.0256
# Epoch 669, cost 0.0222, m grad 0.00517, b grad -0.0254
# Epoch 670, cost 0.0222, m grad 0.00514, b grad -0.0253
# Epoch 671, cost 0.0222, m grad 0.00511, b grad -0.0251
# Epoch 672, cost 0.0222, m grad 0.00508, b grad -0.025
# Epoch 673, cost 0.0222, m grad 0.00505, b grad -0.0248
# Epoch 674, cost 0.0222, m grad 0.00502, b grad -0.0247
# Epoch 675, cost 0.0222, m grad 0.00499, b grad -0.0246
# Epoch 676, cost 0.0222, m grad 0.00497, b grad -0.0244
# Epoch 677, cost 0.0222, m grad 0.00494, b grad -0.0243
# Epoch 678, cost 0.0222, m grad 0.00491, b grad -0.0241
# Epoch 679, cost 0.0222, m grad 0.00488, b grad -0.024
# Epoch 680, cost 0.0222, m grad 0.00485, b grad -0.0239
# Epoch 681, cost 0.0222, m grad 0.00482, b grad -0.0237
# Epoch 682, cost 0.0222, m grad 0.0048, b grad -0.0236
# Epoch 683, cost 0.0222, m grad 0.00477, b grad -0.0234
# Epoch 684, cost 0.0221, m grad 0.00474, b grad -0.0233
# Epoch 685, cost 0.0221, m grad 0.00471, b grad -0.0232
# Epoch 686, cost 0.0221, m grad 0.00469, b grad -0.023
# Epoch 687, cost 0.0221, m grad 0.00466, b grad -0.0229
# Epoch 688, cost 0.0221, m grad 0.00463, b grad -0.0228
# Epoch 689, cost 0.0221, m grad 0.00461, b grad -0.0226
# Epoch 690, cost 0.0221, m grad 0.00458, b grad -0.0225
# Epoch 691, cost 0.0221, m grad 0.00455, b grad -0.0224
# Epoch 692, cost 0.0221, m grad 0.00453, b grad -0.0223
# Epoch 693, cost 0.0221, m grad 0.0045, b grad -0.0221
# Epoch 694, cost 0.0221, m grad 0.00447, b grad -0.022
# Epoch 695, cost 0.0221, m grad 0.00445, b grad -0.0219
# Epoch 696, cost 0.0221, m grad 0.00442, b grad -0.0217
# Epoch 697, cost 0.0221, m grad 0.0044, b grad -0.0216
# Epoch 698, cost 0.0221, m grad 0.00437, b grad -0.0215
# Epoch 699, cost 0.0221, m grad 0.00435, b grad -0.0214
# Epoch 700, cost 0.0221, m grad 0.00432, b grad -0.0213
# Epoch 701, cost 0.0221, m grad 0.0043, b grad -0.0211
# Epoch 702, cost 0.0221, m grad 0.00427, b grad -0.021
# Epoch 703, cost 0.0221, m grad 0.00425, b grad -0.0209
# Epoch 704, cost 0.022, m grad 0.00422, b grad -0.0208
# Epoch 705, cost 0.022, m grad 0.0042, b grad -0.0206
# Epoch 706, cost 0.022, m grad 0.00417, b grad -0.0205
# Epoch 707, cost 0.022, m grad 0.00415, b grad -0.0204
# Epoch 708, cost 0.022, m grad 0.00413, b grad -0.0203
# Epoch 709, cost 0.022, m grad 0.0041, b grad -0.0202
# Epoch 710, cost 0.022, m grad 0.00408, b grad -0.0201
# Epoch 711, cost 0.022, m grad 0.00406, b grad -0.0199
# Epoch 712, cost 0.022, m grad 0.00403, b grad -0.0198
# Epoch 713, cost 0.022, m grad 0.00401, b grad -0.0197
# Epoch 714, cost 0.022, m grad 0.00398, b grad -0.0196
# Epoch 715, cost 0.022, m grad 0.00396, b grad -0.0195
# Epoch 716, cost 0.022, m grad 0.00394, b grad -0.0194
# Epoch 717, cost 0.022, m grad 0.00392, b grad -0.0193
# Epoch 718, cost 0.022, m grad 0.00389, b grad -0.0192
# Epoch 719, cost 0.022, m grad 0.00387, b grad -0.019
# Epoch 720, cost 0.022, m grad 0.00385, b grad -0.0189
# Epoch 721, cost 0.022, m grad 0.00383, b grad -0.0188
# Epoch 722, cost 0.022, m grad 0.00381, b grad -0.0187
# Epoch 723, cost 0.022, m grad 0.00378, b grad -0.0186
# Epoch 724, cost 0.022, m grad 0.00376, b grad -0.0185
# Epoch 725, cost 0.022, m grad 0.00374, b grad -0.0184
# Epoch 726, cost 0.022, m grad 0.00372, b grad -0.0183
# Epoch 727, cost 0.022, m grad 0.0037, b grad -0.0182
# Epoch 728, cost 0.022, m grad 0.00368, b grad -0.0181
# Epoch 729, cost 0.022, m grad 0.00365, b grad -0.018
# Epoch 730, cost 0.0219, m grad 0.00363, b grad -0.0179
# Epoch 731, cost 0.0219, m grad 0.00361, b grad -0.0178
# Epoch 732, cost 0.0219, m grad 0.00359, b grad -0.0177
# Epoch 733, cost 0.0219, m grad 0.00357, b grad -0.0176
# Epoch 734, cost 0.0219, m grad 0.00355, b grad -0.0175
# Epoch 735, cost 0.0219, m grad 0.00353, b grad -0.0174
# Epoch 736, cost 0.0219, m grad 0.00351, b grad -0.0173
# Epoch 737, cost 0.0219, m grad 0.00349, b grad -0.0172
# Epoch 738, cost 0.0219, m grad 0.00347, b grad -0.0171
# Epoch 739, cost 0.0219, m grad 0.00345, b grad -0.017
# Epoch 740, cost 0.0219, m grad 0.00343, b grad -0.0169
# Epoch 741, cost 0.0219, m grad 0.00341, b grad -0.0168
# Epoch 742, cost 0.0219, m grad 0.00339, b grad -0.0167
# Epoch 743, cost 0.0219, m grad 0.00337, b grad -0.0166
# Epoch 744, cost 0.0219, m grad 0.00335, b grad -0.0165
# Epoch 745, cost 0.0219, m grad 0.00333, b grad -0.0164
# Epoch 746, cost 0.0219, m grad 0.00331, b grad -0.0163
# Epoch 747, cost 0.0219, m grad 0.00329, b grad -0.0162
# Epoch 748, cost 0.0219, m grad 0.00327, b grad -0.0161
# Epoch 749, cost 0.0219, m grad 0.00325, b grad -0.016
# Epoch 750, cost 0.0219, m grad 0.00324, b grad -0.0159
# Epoch 751, cost 0.0219, m grad 0.00322, b grad -0.0158
# Epoch 752, cost 0.0219, m grad 0.0032, b grad -0.0157
# Epoch 753, cost 0.0219, m grad 0.00318, b grad -0.0156
# Epoch 754, cost 0.0219, m grad 0.00316, b grad -0.0156
# Epoch 755, cost 0.0219, m grad 0.00314, b grad -0.0155
# Epoch 756, cost 0.0219, m grad 0.00313, b grad -0.0154
# Epoch 757, cost 0.0219, m grad 0.00311, b grad -0.0153
# Epoch 758, cost 0.0219, m grad 0.00309, b grad -0.0152
# Epoch 759, cost 0.0219, m grad 0.00307, b grad -0.0151
# Epoch 760, cost 0.0219, m grad 0.00305, b grad -0.015
# Epoch 761, cost 0.0219, m grad 0.00304, b grad -0.0149
# Epoch 762, cost 0.0219, m grad 0.00302, b grad -0.0148
# Epoch 763, cost 0.0219, m grad 0.003, b grad -0.0148
# Epoch 764, cost 0.0219, m grad 0.00298, b grad -0.0147
# Epoch 765, cost 0.0219, m grad 0.00297, b grad -0.0146
# Epoch 766, cost 0.0218, m grad 0.00295, b grad -0.0145
# Epoch 767, cost 0.0218, m grad 0.00293, b grad -0.0144
# Epoch 768, cost 0.0218, m grad 0.00292, b grad -0.0143
# Epoch 769, cost 0.0218, m grad 0.0029, b grad -0.0143
# Epoch 770, cost 0.0218, m grad 0.00288, b grad -0.0142
# Epoch 771, cost 0.0218, m grad 0.00287, b grad -0.0141
# Epoch 772, cost 0.0218, m grad 0.00285, b grad -0.014
# Epoch 773, cost 0.0218, m grad 0.00284, b grad -0.0139
# Epoch 774, cost 0.0218, m grad 0.00282, b grad -0.0139
# Epoch 775, cost 0.0218, m grad 0.0028, b grad -0.0138
# Epoch 776, cost 0.0218, m grad 0.00279, b grad -0.0137
# Epoch 777, cost 0.0218, m grad 0.00277, b grad -0.0136
# Epoch 778, cost 0.0218, m grad 0.00275, b grad -0.0135
# Epoch 779, cost 0.0218, m grad 0.00274, b grad -0.0135
# Epoch 780, cost 0.0218, m grad 0.00272, b grad -0.0134
# Epoch 781, cost 0.0218, m grad 0.0027, b grad -0.0133
# Epoch 782, cost 0.0218, m grad 0.00269, b grad -0.0132
# Epoch 783, cost 0.0218, m grad 0.00267, b grad -0.0132
# Epoch 784, cost 0.0218, m grad 0.00266, b grad -0.0131
# Epoch 785, cost 0.0218, m grad 0.00264, b grad -0.013
# Epoch 786, cost 0.0218, m grad 0.00263, b grad -0.0129
# Epoch 787, cost 0.0218, m grad 0.00261, b grad -0.0129
# Epoch 788, cost 0.0218, m grad 0.0026, b grad -0.0128
# Epoch 789, cost 0.0218, m grad 0.00258, b grad -0.0127
# Epoch 790, cost 0.0218, m grad 0.00257, b grad -0.0126
# Epoch 791, cost 0.0218, m grad 0.00255, b grad -0.0126
# Epoch 792, cost 0.0218, m grad 0.00254, b grad -0.0125
# Epoch 793, cost 0.0218, m grad 0.00253, b grad -0.0124
# Epoch 794, cost 0.0218, m grad 0.00251, b grad -0.0123
# Epoch 795, cost 0.0218, m grad 0.0025, b grad -0.0123
# Epoch 796, cost 0.0218, m grad 0.00248, b grad -0.0122
# Epoch 797, cost 0.0218, m grad 0.00247, b grad -0.0121
# Epoch 798, cost 0.0218, m grad 0.00245, b grad -0.0121
# Epoch 799, cost 0.0218, m grad 0.00244, b grad -0.012
# Epoch 800, cost 0.0218, m grad 0.00243, b grad -0.0119
# Epoch 801, cost 0.0218, m grad 0.00241, b grad -0.0119
# Epoch 802, cost 0.0218, m grad 0.0024, b grad -0.0118
# Epoch 803, cost 0.0218, m grad 0.00238, b grad -0.0117
# Epoch 804, cost 0.0218, m grad 0.00237, b grad -0.0116
# Epoch 805, cost 0.0218, m grad 0.00235, b grad -0.0116
# Epoch 806, cost 0.0218, m grad 0.00234, b grad -0.0115
# Epoch 807, cost 0.0218, m grad 0.00233, b grad -0.0114
# Epoch 808, cost 0.0218, m grad 0.00232, b grad -0.0114
# Epoch 809, cost 0.0218, m grad 0.0023, b grad -0.0113
# Epoch 810, cost 0.0218, m grad 0.00229, b grad -0.0112
# Epoch 811, cost 0.0218, m grad 0.00227, b grad -0.0112
# Epoch 812, cost 0.0218, m grad 0.00226, b grad -0.0111
# Epoch 813, cost 0.0218, m grad 0.00225, b grad -0.0111
# Epoch 814, cost 0.0218, m grad 0.00224, b grad -0.011
# Epoch 815, cost 0.0218, m grad 0.00222, b grad -0.0109
# Epoch 816, cost 0.0218, m grad 0.00221, b grad -0.0109
# Epoch 817, cost 0.0218, m grad 0.0022, b grad -0.0108
# Epoch 818, cost 0.0218, m grad 0.00218, b grad -0.0107
# Epoch 819, cost 0.0218, m grad 0.00217, b grad -0.0107
# Epoch 820, cost 0.0218, m grad 0.00216, b grad -0.0106
# Epoch 821, cost 0.0218, m grad 0.00215, b grad -0.0106
# Epoch 822, cost 0.0218, m grad 0.00213, b grad -0.0105
# Epoch 823, cost 0.0218, m grad 0.00212, b grad -0.0104
# Epoch 824, cost 0.0218, m grad 0.00211, b grad -0.0104
# Epoch 825, cost 0.0218, m grad 0.0021, b grad -0.0103
# Epoch 826, cost 0.0218, m grad 0.00209, b grad -0.0103
# Epoch 827, cost 0.0218, m grad 0.00207, b grad -0.0102
# Epoch 828, cost 0.0218, m grad 0.00206, b grad -0.0101
# Epoch 829, cost 0.0218, m grad 0.00205, b grad -0.0101
# Epoch 830, cost 0.0217, m grad 0.00204, b grad -0.01
# Epoch 831, cost 0.0217, m grad 0.00203, b grad -0.00996
# Epoch 832, cost 0.0217, m grad 0.00201, b grad -0.00991
# Epoch 833, cost 0.0217, m grad 0.002, b grad -0.00985
# Epoch 834, cost 0.0217, m grad 0.00199, b grad -0.00979
# Epoch 835, cost 0.0217, m grad 0.00198, b grad -0.00974
# Epoch 836, cost 0.0217, m grad 0.00197, b grad -0.00968
# Epoch 837, cost 0.0217, m grad 0.00196, b grad -0.00962
# Epoch 838, cost 0.0217, m grad 0.00195, b grad -0.00957
# Epoch 839, cost 0.0217, m grad 0.00193, b grad -0.00951
# Epoch 840, cost 0.0217, m grad 0.00192, b grad -0.00946
# Epoch 841, cost 0.0217, m grad 0.00191, b grad -0.0094
# Epoch 842, cost 0.0217, m grad 0.0019, b grad -0.00935
# Epoch 843, cost 0.0217, m grad 0.00189, b grad -0.0093
# Epoch 844, cost 0.0217, m grad 0.00188, b grad -0.00924
# Epoch 845, cost 0.0217, m grad 0.00187, b grad -0.00919
# Epoch 846, cost 0.0217, m grad 0.00186, b grad -0.00914
# Epoch 847, cost 0.0217, m grad 0.00185, b grad -0.00908
# Epoch 848, cost 0.0217, m grad 0.00184, b grad -0.00903
# Epoch 849, cost 0.0217, m grad 0.00183, b grad -0.00898
# Epoch 850, cost 0.0217, m grad 0.00182, b grad -0.00893
# Epoch 851, cost 0.0217, m grad 0.0018, b grad -0.00888
# Epoch 852, cost 0.0217, m grad 0.00179, b grad -0.00882
# Epoch 853, cost 0.0217, m grad 0.00178, b grad -0.00877
# Epoch 854, cost 0.0217, m grad 0.00177, b grad -0.00872
# Epoch 855, cost 0.0217, m grad 0.00176, b grad -0.00867
# Epoch 856, cost 0.0217, m grad 0.00175, b grad -0.00862
# Epoch 857, cost 0.0217, m grad 0.00174, b grad -0.00857
# Epoch 858, cost 0.0217, m grad 0.00174, b grad -0.00852
# Epoch 859, cost 0.0217, m grad 0.00172, b grad -0.00847
# Epoch 860, cost 0.0217, m grad 0.00171, b grad -0.00843
# Epoch 861, cost 0.0217, m grad 0.0017, b grad -0.00838
# Epoch 862, cost 0.0217, m grad 0.00169, b grad -0.00833
# Epoch 863, cost 0.0217, m grad 0.00168, b grad -0.00828
# Epoch 864, cost 0.0217, m grad 0.00167, b grad -0.00823
# Epoch 865, cost 0.0217, m grad 0.00166, b grad -0.00819
# Epoch 866, cost 0.0217, m grad 0.00165, b grad -0.00814
# Epoch 867, cost 0.0217, m grad 0.00164, b grad -0.00809
# Epoch 868, cost 0.0217, m grad 0.00163, b grad -0.00805
# Epoch 869, cost 0.0217, m grad 0.00162, b grad -0.008
# Epoch 870, cost 0.0217, m grad 0.00162, b grad -0.00795
# Epoch 871, cost 0.0217, m grad 0.00161, b grad -0.00791
# Epoch 872, cost 0.0217, m grad 0.0016, b grad -0.00786
# Epoch 873, cost 0.0217, m grad 0.00159, b grad -0.00782
# Epoch 874, cost 0.0217, m grad 0.00158, b grad -0.00777
# Epoch 875, cost 0.0217, m grad 0.00157, b grad -0.00773
# Epoch 876, cost 0.0217, m grad 0.00156, b grad -0.00768
# Epoch 877, cost 0.0217, m grad 0.00155, b grad -0.00764
# Epoch 878, cost 0.0217, m grad 0.00154, b grad -0.00759
# Epoch 879, cost 0.0217, m grad 0.00153, b grad -0.00755
# Epoch 880, cost 0.0217, m grad 0.00153, b grad -0.00751
# Epoch 881, cost 0.0217, m grad 0.00152, b grad -0.00746
# Epoch 882, cost 0.0217, m grad 0.00151, b grad -0.00742
# Epoch 883, cost 0.0217, m grad 0.0015, b grad -0.00738
# Epoch 884, cost 0.0217, m grad 0.00149, b grad -0.00733
# Epoch 885, cost 0.0217, m grad 0.00148, b grad -0.00729
# Epoch 886, cost 0.0217, m grad 0.00147, b grad -0.00725
# Epoch 887, cost 0.0217, m grad 0.00147, b grad -0.00721
# Epoch 888, cost 0.0217, m grad 0.00146, b grad -0.00717
# Epoch 889, cost 0.0217, m grad 0.00145, b grad -0.00712
# Epoch 890, cost 0.0217, m grad 0.00144, b grad -0.00708
# Epoch 891, cost 0.0217, m grad 0.00143, b grad -0.00704
# Epoch 892, cost 0.0217, m grad 0.00142, b grad -0.007
# Epoch 893, cost 0.0217, m grad 0.00142, b grad -0.00696
# Epoch 894, cost 0.0217, m grad 0.00141, b grad -0.00692
# Epoch 895, cost 0.0217, m grad 0.0014, b grad -0.00688
# Epoch 896, cost 0.0217, m grad 0.00139, b grad -0.00684
# Epoch 897, cost 0.0217, m grad 0.00138, b grad -0.0068
# Epoch 898, cost 0.0217, m grad 0.00137, b grad -0.00676
# Epoch 899, cost 0.0217, m grad 0.00137, b grad -0.00672
# Epoch 900, cost 0.0217, m grad 0.00136, b grad -0.00669
# Epoch 901, cost 0.0217, m grad 0.00135, b grad -0.00665
# Epoch 902, cost 0.0217, m grad 0.00134, b grad -0.00661
# Epoch 903, cost 0.0217, m grad 0.00134, b grad -0.00657
# Epoch 904, cost 0.0217, m grad 0.00133, b grad -0.00653
# Epoch 905, cost 0.0217, m grad 0.00132, b grad -0.0065
# Epoch 906, cost 0.0217, m grad 0.00131, b grad -0.00646
# Epoch 907, cost 0.0217, m grad 0.00131, b grad -0.00642
# Epoch 908, cost 0.0217, m grad 0.0013, b grad -0.00638
# Epoch 909, cost 0.0217, m grad 0.00129, b grad -0.00635
# Epoch 910, cost 0.0217, m grad 0.00128, b grad -0.00631
# Epoch 911, cost 0.0217, m grad 0.00128, b grad -0.00627
# Epoch 912, cost 0.0217, m grad 0.00127, b grad -0.00624
# Epoch 913, cost 0.0217, m grad 0.00126, b grad -0.0062
# Epoch 914, cost 0.0217, m grad 0.00125, b grad -0.00617
# Epoch 915, cost 0.0217, m grad 0.00125, b grad -0.00613
# Epoch 916, cost 0.0217, m grad 0.00124, b grad -0.0061
# Epoch 917, cost 0.0217, m grad 0.00123, b grad -0.00606
# Epoch 918, cost 0.0217, m grad 0.00123, b grad -0.00602
# Epoch 919, cost 0.0217, m grad 0.00122, b grad -0.00599
# Epoch 920, cost 0.0217, m grad 0.00121, b grad -0.00596
# Epoch 921, cost 0.0217, m grad 0.0012, b grad -0.00592
# Epoch 922, cost 0.0217, m grad 0.0012, b grad -0.00589
# Epoch 923, cost 0.0217, m grad 0.00119, b grad -0.00585
# Epoch 924, cost 0.0217, m grad 0.00118, b grad -0.00582
# Epoch 925, cost 0.0217, m grad 0.00118, b grad -0.00579
# Epoch 926, cost 0.0217, m grad 0.00117, b grad -0.00575
# Epoch 927, cost 0.0217, m grad 0.00116, b grad -0.00572
# Epoch 928, cost 0.0217, m grad 0.00116, b grad -0.00569
# Epoch 929, cost 0.0217, m grad 0.00115, b grad -0.00565
# Epoch 930, cost 0.0217, m grad 0.00114, b grad -0.00562
# Epoch 931, cost 0.0217, m grad 0.00114, b grad -0.00559
# Epoch 932, cost 0.0217, m grad 0.00113, b grad -0.00556
# Epoch 933, cost 0.0217, m grad 0.00112, b grad -0.00552
# Epoch 934, cost 0.0217, m grad 0.00112, b grad -0.00549
# Epoch 935, cost 0.0217, m grad 0.00111, b grad -0.00546
# Epoch 936, cost 0.0217, m grad 0.0011, b grad -0.00543
# Epoch 937, cost 0.0217, m grad 0.0011, b grad -0.0054
# Epoch 938, cost 0.0217, m grad 0.00109, b grad -0.00537
# Epoch 939, cost 0.0217, m grad 0.00109, b grad -0.00534
# Epoch 940, cost 0.0217, m grad 0.00108, b grad -0.00531
# Epoch 941, cost 0.0217, m grad 0.00107, b grad -0.00527
# Epoch 942, cost 0.0217, m grad 0.00107, b grad -0.00524
# Epoch 943, cost 0.0217, m grad 0.00106, b grad -0.00521
# Epoch 944, cost 0.0217, m grad 0.00106, b grad -0.00518
# Epoch 945, cost 0.0217, m grad 0.00105, b grad -0.00515
# Epoch 946, cost 0.0217, m grad 0.00104, b grad -0.00512
# Epoch 947, cost 0.0217, m grad 0.00104, b grad -0.00509
# Epoch 948, cost 0.0217, m grad 0.00103, b grad -0.00507
# Epoch 949, cost 0.0217, m grad 0.00102, b grad -0.00504
# Epoch 950, cost 0.0217, m grad 0.00102, b grad -0.00501
# Epoch 951, cost 0.0217, m grad 0.00101, b grad -0.00498
# Epoch 952, cost 0.0217, m grad 0.00101, b grad -0.00495
# Epoch 953, cost 0.0217, m grad 0.001, b grad -0.00492
# Epoch 954, cost 0.0217, m grad 0.000994, b grad -0.00489
# Epoch 955, cost 0.0217, m grad 0.000988, b grad -0.00486
# Epoch 956, cost 0.0217, m grad 0.000983, b grad -0.00484
# Epoch 957, cost 0.0217, m grad 0.000977, b grad -0.00481
# Epoch 958, cost 0.0217, m grad 0.000972, b grad -0.00478
# Epoch 959, cost 0.0217, m grad 0.000968, b grad -0.00475
# Epoch 960, cost 0.0217, m grad 0.000961, b grad -0.00473
# Epoch 961, cost 0.0217, m grad 0.000955, b grad -0.0047
# Epoch 962, cost 0.0217, m grad 0.00095, b grad -0.00467
# Epoch 963, cost 0.0217, m grad 0.000944, b grad -0.00464
# Epoch 964, cost 0.0217, m grad 0.000939, b grad -0.00462
# Epoch 965, cost 0.0217, m grad 0.000934, b grad -0.00459
# Epoch 966, cost 0.0217, m grad 0.00093, b grad -0.00456
# Epoch 967, cost 0.0217, m grad 0.000923, b grad -0.00454
# Epoch 968, cost 0.0217, m grad 0.000917, b grad -0.00451
# Epoch 969, cost 0.0217, m grad 0.000911, b grad -0.00449
# Epoch 970, cost 0.0217, m grad 0.000905, b grad -0.00446
# Epoch 971, cost 0.0217, m grad 0.0009, b grad -0.00444
# Epoch 972, cost 0.0217, m grad 0.000896, b grad -0.00441
# Epoch 973, cost 0.0217, m grad 0.000891, b grad -0.00438
# Epoch 974, cost 0.0217, m grad 0.000886, b grad -0.00436
# Epoch 975, cost 0.0217, m grad 0.000881, b grad -0.00433
# Epoch 976, cost 0.0217, m grad 0.000876, b grad -0.00431
# Epoch 977, cost 0.0217, m grad 0.000872, b grad -0.00428
# Epoch 978, cost 0.0217, m grad 0.000867, b grad -0.00426
# Epoch 979, cost 0.0217, m grad 0.000862, b grad -0.00423
# Epoch 980, cost 0.0217, m grad 0.000857, b grad -0.00421
# Epoch 981, cost 0.0217, m grad 0.000852, b grad -0.00419
# Epoch 982, cost 0.0217, m grad 0.000848, b grad -0.00416
# Epoch 983, cost 0.0217, m grad 0.000843, b grad -0.00414
# Epoch 984, cost 0.0217, m grad 0.000838, b grad -0.00411
# Epoch 985, cost 0.0217, m grad 0.000834, b grad -0.00409
# Epoch 986, cost 0.0217, m grad 0.000829, b grad -0.00407
# Epoch 987, cost 0.0217, m grad 0.000824, b grad -0.00404
# Epoch 988, cost 0.0217, m grad 0.000819, b grad -0.00402
# Epoch 989, cost 0.0217, m grad 0.000814, b grad -0.004
# Epoch 990, cost 0.0217, m grad 0.00081, b grad -0.00397
# Epoch 991, cost 0.0217, m grad 0.000805, b grad -0.00395
# Epoch 992, cost 0.0217, m grad 0.0008, b grad -0.00393
# Epoch 993, cost 0.0217, m grad 0.000796, b grad -0.0039
# Epoch 994, cost 0.0217, m grad 0.000791, b grad -0.00388
# Epoch 995, cost 0.0217, m grad 0.000787, b grad -0.00386
# Epoch 996, cost 0.0217, m grad 0.000782, b grad -0.00384
# Epoch 997, cost 0.0217, m grad 0.000777, b grad -0.00381
# Epoch 998, cost 0.0217, m grad 0.000772, b grad -0.00379
# Epoch 999, cost 0.0217, m grad 0.000767, b grad -0.00377

# %%
regression_plot(x, y, m, b)

# %%
m.item()
# Out:
# -0.4902859926223755

# %%
b.item()
# Out:
# 2.0210249423980713
